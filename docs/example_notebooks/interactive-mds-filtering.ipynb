# %% [markdown]
# # Interactive Quality Control Pipeline

# %%
import methylcheck
from pathlib import Path

# %% [markdown]
# In the interactive version (`run_pipeline`), it tries a filtering technique called multi-dimensional scaling to detect outlier samples in a batch. Then lets you look at the output and adjust some parameters, until you think it has the best separation.

# %%
filepath = Path('/Volumes/LEGX/Barnes/illumina/temp/')
df = methylcheck.load(filepath)
methylcheck.run_pipeline(df)
# Out:
# Files: 100%|██████████| 1/1 [00:01<00:00,  1.63s/it]
# INFO:methylcheck.load_processed:loaded data (236685, 120) from 1 pickled files (0.168s)
# INFO:methylcheck.probes.filters:No probe exclusion lists available for mouse arrays at this time.
# INFO:methylcheck.probes.filters:No probe exclusion lists available for mouse arrays at this time.
# INFO:methylcheck.qc_report:No probe exclusion lists available for mouse arrays at this time.
# WARNING:methylcheck.samples.postprocessQC:Your data contains 52597 missing probe values per sample, (6311661 overall). For a list per sample, use verbose=True
# Calculating area under curve for each sample.
# 120it [00:03, 37.07it/s]
# INFO:methylcheck.samples.postprocessQC:52597.2 probe(s) [avg per sample] were missing values and removed from MDS calculations; 236685 remaining.
# 120 original samples; 91 after filtering
# Your scale factor was: 1.5
# Enter new scale factor, <enter> to accept and save:
# ...
